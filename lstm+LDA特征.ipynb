# %%
import sys
import pickle
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense, Embedding, Dropout
from tensorflow.keras.layers import SimpleRNN, LSTM, GRU, Bidirectional, concatenate
from tensorflow.keras import preprocessing
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau, TensorBoard
from tensorflow.keras import Input
from tensorflow.keras import optimizers
from tensorflow.keras.models import load_model
import matplotlib.pyplot as plt
from attention import AttentionLayer #ok
import pprint

# %%
#参数配置
class Config(object):

    #数据集路径
    project_name = "output666\\lucene"

    #训练参数
    num_hidden = 100
    num_layer = 3
    non_static = True

    summary_length = 3386
    description_length = 18620
    priority_length = 6
    theme_length = 2
    n_epoch = 10
    batch_size = 32
    num_classes = 2
    dropoutKeepProb = 0.3

    #保存路径
    log_dir = 'LSTM_log\\all'
    model_dir = 'com_LSTM_model\\LSTM_lucene_withLDA.h5'

# %%
def split_data(data):
    '''将数据中的句向量和标签取出'''
    s_data, d_data, p_data, t_data, l_data = [], [], [], [], []
    for d in data:
        s_data.append(d[1])
        d_data.append(d[2])
        p_data.append(d[3])
        t_data.append(d[4])
        l_data.append(d[5])
    s_data = np.asarray(s_data, dtype="int64")
    d_data = np.asarray(d_data, dtype="int64")
    p_data = np.asarray(p_data, dtype="int64")
    t_data = np.asarray(t_data, dtype="int64")
    l_data = np.asarray(l_data, dtype="int64")
    return s_data, d_data, p_data, t_data, l_data

# %%
def load_data(config):
    print("function : load data")
    print("type of batch_size : ", type(config.batch_size))
    train_data = pickle.load(open(config.project_name + "/train_nn.pkl", "rb"))
    valid_data = pickle.load(open(config.project_name + "/valid_nn.pkl", "rb"))
    test_data = pickle.load(open(config.project_name + "/test_nn.pkl", "rb"))
    print("train data :", len(train_data))
    print("valid data :", len(valid_data))
    print("test data :", len(test_data))
    return train_data, valid_data, test_data

# %%
def build_model(config):
    '''构建模型'''
    print("build the model")
    #论文基本模型 函数式
    #summary
    input_summary = Input(shape=(50,), dtype='int64', name='summary')
    embedded_summary = Embedding(config.summary_length, 32)(input_summary)
    encode_summary = LSTM(16)(embedded_summary)

    #description
    input_description = Input(shape=(100,), dtype='int64', name='description')
    embedded_description = Embedding(config.description_length, 32)(input_description)
    encode_description = LSTM(16)(embedded_description)

    #priority
    input_priority = Input(shape=(1,), dtype='int64', name='priority')
    embedded_priority = Embedding(config.priority_length, 8)(input_priority)
    encode_priority = Flatten()(embedded_priority)
    
    #theme
    input_theme = Input(shape=(100,), dtype='int64', name='theme')
    embedded_theme = Embedding(config.theme_length, 8)(input_theme)
    encode_theme = Flatten()(embedded_theme)
    
    #concat
    concatenated = concatenate([encode_summary, encode_description, encode_priority, encode_theme], axis=-1)
    den_1 = Dense(64, activation='relu')(concatenated)
    drop_1 = Dropout(config.dropoutKeepProb)(den_1)
    den_2 = Dense(64, activation='relu')(drop_1)
    drop_2 = Dropout(config.dropoutKeepProb)(den_2)
    output = Dense(1, activation='sigmoid')(drop_2)
#     output = Dense(1, activation='sigmoid')(drop_1)
    
    model = Model([input_summary, input_description, input_priority, input_theme], output)
    
    rmsprop = optimizers.RMSprop(lr=0.001, rho=0.9, epsilon=None, decay=0.0)

    model.compile(optimizer=rmsprop,  # adam rmsprop
              loss='binary_crossentropy',  # mse binary_crossentropy
              metrics=['acc']) #metrics=['acc', precision, recall, f1]
    model.summary()
    
    return model

# %%
def train(config):
    #定义回调函数
    callbacks_list = [
        ReduceLROnPlateau(
            # 当验证集上loss连续三个epoch不改变时，将学习率降低为原来的十分之一
            monitor='val_loss',
            factor=0.1,
            patience=3
        ),
        ModelCheckpoint(
            # 仅保存在验证集上表现最好的模型
            filepath=config.model_dir,
            monitor='val_loss',
            save_best_only=True
        ),
    ]
    
    history = model.fit([train_summary, train_description, train_priority, train_theme], train_label,
                    epochs=config.n_epoch,
                    batch_size=config.batch_size,
                    callbacks=callbacks_list,
                    validation_data=([valid_summary, valid_description, valid_priority, valid_theme], valid_label))
    return history

# %%
def evaluate(config):
    #模型评估
    model = load_model(config.model_dir)
    results = model.evaluate([test_summary, test_description, test_priority, test_theme], test_label)
#     pprint.pprint('评估结果:', results)
    print(results)

# %%
def draw():
    #绘制结果
    history_dict = history.history
#     print(history_dict)

    train_acc = history_dict['acc']
    val_acc = history_dict['val_acc']
    train_loss = history_dict['loss']
    val_loss = history_dict['val_loss']

    epochs = range(1, len(train_acc) + 1)

    plt.plot(epochs, train_loss, 'bo', label='Training loss')
    plt.plot(epochs, val_loss, 'b', label='Validation loss')
    plt.title('Training and validation loss of lucene')
    plt.legend()
    plt.show()

    plt.plot(epochs, train_acc, 'go', label='Training acc')
    plt.plot(epochs, val_acc, 'g', label='Validation acc')
    plt.title('Training and validation accuracy of lucene')
    plt.legend()
    plt.show()

# %%
if __name__ == '__main__':
    config = Config()
    train_data, valid_data, test_data = load_data(config)
    '''分离数据中的句子和标签'''
    train_summary, train_description, train_priority, train_theme, train_label = split_data(train_data)
    valid_summary, valid_description, valid_priority, valid_theme, valid_label = split_data(valid_data)
    test_summary, test_description, test_priority, test_theme, test_label = split_data(test_data)
    print(len(valid_theme))
    print(len(valid_data[0]))
    model = build_model(config)
    
    history = train(config)
    
    evaluate(config)
    
    draw()
# Out:
# function : load data
# type of batch_size :  <class 'int'>
# train data : 1978
# valid data : 220
# test data : 245
# 220
# 6
# build the model
# Model: "model_9"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# summary (InputLayer)            [(None, 50)]         0
# __________________________________________________________________________________________________
# description (InputLayer)        [(None, 100)]        0
# __________________________________________________________________________________________________
# priority (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# theme (InputLayer)              [(None, 100)]        0
# __________________________________________________________________________________________________
# embedding_36 (Embedding)        (None, 50, 32)       108352      summary[0][0]
# __________________________________________________________________________________________________
# embedding_37 (Embedding)        (None, 100, 32)      595840      description[0][0]
# __________________________________________________________________________________________________
# embedding_38 (Embedding)        (None, 1, 8)         48          priority[0][0]
# __________________________________________________________________________________________________
# embedding_39 (Embedding)        (None, 100, 8)       16          theme[0][0]
# __________________________________________________________________________________________________
# lstm_18 (LSTM)                  (None, 16)           3136        embedding_36[0][0]
# __________________________________________________________________________________________________
# lstm_19 (LSTM)                  (None, 16)           3136        embedding_37[0][0]
# __________________________________________________________________________________________________
# flatten_18 (Flatten)            (None, 8)            0           embedding_38[0][0]
# __________________________________________________________________________________________________
# flatten_19 (Flatten)            (None, 800)          0           embedding_39[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 840)          0           lstm_18[0][0]
#                                                                  lstm_19[0][0]
#                                                                  flatten_18[0][0]
#                                                                  flatten_19[0][0]
# __________________________________________________________________________________________________
# dense_26 (Dense)                (None, 64)           53824       concatenate_9[0][0]
# __________________________________________________________________________________________________
# dropout_17 (Dropout)            (None, 64)           0           dense_26[0][0]
# __________________________________________________________________________________________________
# dense_27 (Dense)                (None, 64)           4160        dropout_17[0][0]
# __________________________________________________________________________________________________
# dropout_18 (Dropout)            (None, 64)           0           dense_27[0][0]
# __________________________________________________________________________________________________
# dense_28 (Dense)                (None, 1)            65          dropout_18[0][0]
# ==================================================================================================
# Total params: 768,577
# Trainable params: 768,577
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Train on 1978 samples, validate on 220 samples
# Epoch 1/10
# 1978/1978 [==============================] - 4s 2ms/sample - loss: 0.5992 - acc: 0.7164 - val_loss: 0.5597 - val_acc: 0.7045
# Epoch 2/10
# 1978/1978 [==============================] - 2s 955us/sample - loss: 0.4182 - acc: 0.8119 - val_loss: 0.4747 - val_acc: 0.7818
# Epoch 3/10
# 1978/1978 [==============================] - 2s 939us/sample - loss: 0.2486 - acc: 0.9065 - val_loss: 0.3699 - val_acc: 0.8318
# Epoch 4/10
# 1978/1978 [==============================] - 2s 934us/sample - loss: 0.1502 - acc: 0.9429 - val_loss: 0.3962 - val_acc: 0.8364
# Epoch 5/10
# 1978/1978 [==============================] - 2s 930us/sample - loss: 0.0975 - acc: 0.9651 - val_loss: 0.4232 - val_acc: 0.8455
# Epoch 6/10
# 1978/1978 [==============================] - 2s 925us/sample - loss: 0.0539 - acc: 0.9828 - val_loss: 0.5344 - val_acc: 0.8364
# Epoch 7/10
# 1978/1978 [==============================] - 2s 917us/sample - loss: 0.0199 - acc: 0.9954 - val_loss: 0.6268 - val_acc: 0.8227
# Epoch 8/10
# 1978/1978 [==============================] - 2s 911us/sample - loss: 0.0184 - acc: 0.9970 - val_loss: 0.6147 - val_acc: 0.8409
# Epoch 9/10
# 1978/1978 [==============================] - 2s 909us/sample - loss: 0.0163 - acc: 0.9970 - val_loss: 0.6690 - val_acc: 0.8273
# Epoch 10/10
# 1978/1978 [==============================] - 2s 914us/sample - loss: 0.0119 - acc: 0.9975 - val_loss: 0.6776 - val_acc: 0.8273
# 245/245 [==============================] - 0s 1ms/sample - loss: 0.4488 - acc: 0.7837
# [0.4487957764645012, 0.78367347]
